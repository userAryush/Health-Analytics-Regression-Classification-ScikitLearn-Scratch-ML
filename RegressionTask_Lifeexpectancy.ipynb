# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing necessary libraries required for data preprocessing and visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')#to ignore any warnings generated

# %% [markdown]
# Basic Overview of the Dataset

# %%
life_expectancy_df = pd.read_csv('/content/drive/MyDrive/Life Expectancy Data.csv')

# %%
life_expectancy_df.head(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
# 5             74     0.01               79.679367         66.0      1989  ...
# 6             77     0.01               56.762217         63.0      2861  ...
# 7             80     0.03               25.873925         64.0      1599  ...
# 8             82     0.02               10.910156         63.0      1141  ...
# 9             84     0.03               17.171518         64.0      1990  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
# 5   66.0               9.20         66.0        0.1  553.328940   2883167.0
# 6   63.0               9.42         63.0        0.1  445.893298    284331.0
# 7   64.0               8.33         64.0        0.1  373.361116   2729431.0
# 8   63.0               6.73         63.0        0.1  369.835796  26616792.0
# 9   58.0               7.43         58.0        0.1  272.563770   2589345.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
# 5                   18.4                 18.4
# 6                   18.6                 18.7
# 7                   18.8                 18.9
# 8                   19.0                 19.1
# 9                   19.2                 19.3
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
# 7                            0.433        8.7
# 8                            0.415        8.4
# 9                            0.405        8.1
#
# [10 rows x 22 columns]

# %%
life_expectancy_df.tail(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2928  Zimbabwe  2009  Developing              50.0            587.0
# 2929  Zimbabwe  2008  Developing              48.2            632.0
# 2930  Zimbabwe  2007  Developing              46.6             67.0
# 2931  Zimbabwe  2006  Developing              45.4              7.0
# 2932  Zimbabwe  2005  Developing              44.6            717.0
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2928             30     4.64                1.040021         73.0       853
# 2929             30     3.56               20.843429         75.0         0
# 2930             29     3.88               29.814566         72.0       242
# 2931             28     4.57               34.262169         68.0       212
# 2932             28     4.14                8.717409         65.0       420
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2928  ...   69.0               6.26         73.0       18.1   65.824121
# 2929  ...   75.0               4.96         75.0       20.5  325.678573
# 2930  ...   73.0               4.47         73.0       23.7  396.998217
# 2931  ...   71.0               5.12          7.0       26.8  414.796232
# 2932  ...   69.0               6.44         68.0       30.3  444.765750
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2928   1381599.0                    7.5                  7.4
# 2929  13558469.0                    7.8                  7.8
# 2930   1332999.0                    8.2                  8.2
# 2931  13124267.0                    8.6                  8.6
# 2932    129432.0                    9.0                  9.0
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 2928                            0.419        9.9
# 2929                            0.421        9.7
# 2930                            0.414        9.6
# 2931                            0.408        9.5
# 2932                            0.406        9.3
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [10 rows x 22 columns]

# %%
print(f"The dataset has {life_expectancy_df.shape[0]} rows and {life_expectancy_df.shape[1]} columns.")
# Out:
# The dataset has 2938 rows and 22 columns.

# %%
life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %% [markdown]
# The provided output gives us general idea about the data types that our dataset comprises of. We can observe that the two columns are of object data type while the rest columns consists of both float and integer data type.

# %%
print(f"My Regression Target is\nHeartDisease\n")
life_expectancy_df.iloc[5:15,3]#[rows,column]
# Out:
# My Regression Target is
# HeartDisease
# 5     58.8
# 6     58.6
# 7     58.1
# 8     57.5
# 9     57.3
# 10    57.3
# 11    57.0
# 12    56.7
# 13    56.2
# 14    55.3
# Name: Life expectancy , dtype: float64

# %%
dataset_cols = life_expectancy_df.columns
print("Columns: ",dataset_cols)
# Out:
# Columns:  Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print(f"Total number of duplicated values in the dataset {life_expectancy_df.duplicated().sum()}")
# Out:
# Total number of duplicated values in the dataset 0

# %% [markdown]
# Checking and Handling duplicate values

# %%
print("\nMissing Values:")
print(life_expectancy_df.isnull().sum())
# Out:
# Missing Values:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
categorical_col = life_expectancy_df.select_dtypes(include='object')
numeric_col = life_expectancy_df.select_dtypes(include='number')

# %% [markdown]
# **using median to fill the missing values**

# %%
numberCol = numeric_col.columns  # list of numeric column names
life_expectancy_df[numberCol] = life_expectancy_df[numberCol].fillna(life_expectancy_df[numberCol].median())

# %%
print("\nMissing Values:")
print(life_expectancy_df.isnull().sum())
# Out:
# Missing Values:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# The missing values have been successfully handled.

# %% [markdown]
# Statistics

# %%
numeric_col.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
print(categorical_col.describe())
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %% [markdown]
# The summary statistics show that for Country column, Afghanistan is the most occuring country with frequency of 16 and for Status column, Developing is the most occuring status with the frequency of 2426.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.figure(figsize=(15,6))
sns.histplot(life_expectancy_df['Life expectancy '],kde=True)
plt.title("Life expectancy distribution")
plt.show()

# %% [markdown]
# The above plot shows the distribution of our target column. We can observe that it is left skewed with its median being greater than mean.

# %% [markdown]
# **countplot of our status column**

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=life_expectancy_df['Status'],palette='viridis')
plt.show()
life_expectancy_df["Status"].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %% [markdown]
# The above plot shows that the Developing clearly outnumbers other classe. This shows that there is high frequency of countries with the status Developing compared to Developed.

# %% [markdown]
# **Scatter plot between Adult Mortality(Feature) and Life Expectancy(target)**

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=life_expectancy_df,x="Adult Mortality",y="Life expectancy ")
plt.title("Life expectancy vs Adult Mortalilty")
plt.show()

# %% [markdown]
# The above scatterplot shows the relationship between Adult Mortality and Life expectancy. We can observe a strong negative correlation between the two variables. As the Adult Mortality rate increases, the life expectancy can be observed significantly decreasing . This shows us that life expectancy is affected byu Adult Mortality rate.

# %% [markdown]
# **Scatter plot between Schooling(Feature) and Life Expectancy(target)**

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=life_expectancy_df,x="Schooling",y="Life expectancy ")
plt.title("Life expectancy vs Schooling")
plt.show()

# %% [markdown]
# The above scatterplot shows the relationship between Schooling and Life expectancy. We can observe a strong positive correlation between the two variables. As the Schooling rate increases, the life expectancy can be observed significantly increasing . This shows us that life expectancy is affected by Schooling.

# %% [markdown]
# **Dropping the country column as it is not useful for prediciting life expectancy**

# %%
life_expectancy_df.drop(columns="Country", inplace=True)

# %% [markdown]
# **Encoding the Status column to numeric value**

# %%
life_expectancy_df["Status"]=[0 if i == "Developing" else 1  for i in life_expectancy_df["Status"]]

# %%
life_expectancy_df.head(3)
# Out:
#    Year  Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015       0              65.0            263.0             62     0.01
# 1  2014       0              59.9            271.0             64     0.01
# 2  2013       0              59.9            268.0             66     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               71.279624         65.0      1154   19.1  ...    6.0
# 1               73.523582         62.0       492   18.6  ...   58.0
# 2               73.219243         64.0       430   18.1  ...   62.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
#
# [3 rows x 21 columns]

# %%
# quartiles and IQR
Q1 = life_expectancy_df['Life expectancy '].quantile(0.25)
Q3 = life_expectancy_df['Life expectancy '].quantile(0.75)
IQR = Q3 - Q1

#outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# outliers
outliers = life_expectancy_df[(life_expectancy_df['Life expectancy '] < lower_bound) | (life_expectancy_df['Life expectancy '] > upper_bound)]

# boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(y=life_expectancy_df['Life expectancy '], color='skyblue')
plt.title('Life Expectancy Boxplot with Outliers')
plt.ylabel('Life Expectancy')

# Highlight outliers
plt.scatter(x=[0] * len(outliers), y=outliers['Life expectancy '], color='red', label='Outliers')
plt.legend()
plt.show()

print(f"Number of outliers: {len(outliers)}")
print(f"Outliers:\n{outliers}")
# Out:
# Number of outliers: 17
# Outliers:
#       Year  Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 1127  2010       0              36.3            682.0             23     5.76
# 1484  2005       0              44.5            675.0              5     2.67
# 1582  2003       0              44.6            613.0             43     1.08
# 1583  2002       0              44.0             67.0             46     1.10
# 1584  2001       0              43.5            599.0             48     1.15
# 1585  2000       0              43.1            588.0             51     1.18
# 2306  2006       0              44.3            464.0             30     3.80
# 2307  2005       0              43.3             48.0             30     3.83
# 2308  2004       0              42.3            496.0             30     3.99
# 2309  2003       0              41.5             57.0             30     4.07
# 2311  2001       0              41.0            519.0             30     4.21
# 2312  2000       0              39.0            533.0             29     3.97
# 2920  2001       0              44.6            611.0             43     2.61
# 2921  2000       0              43.8            614.0             44     2.62
# 2932  2005       0              44.6            717.0             28     4.14
# 2933  2004       0              44.3            723.0             27     4.36
# 2934  2003       0              44.5            715.0             26     4.06
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 1127               36.292918         92.0         0   44.2  ...   66.0
# 1484               57.903698         87.0         0   27.4  ...   88.0
# 1582                4.375316         84.0       167   15.2  ...   85.0
# 1583                3.885395         64.0        92   14.8  ...   79.0
# 1584               12.797606         92.0       150   14.4  ...   86.0
# 1585               13.762702         92.0       304   14.1  ...   73.0
# 2306               38.000758         92.0        33   19.7  ...   65.0
# 2307               42.088929         92.0        29   19.2  ...   67.0
# 2308               38.524548         92.0         7   18.8  ...   69.0
# 2309               38.614732         92.0       586   18.4  ...   66.0
# 2311               33.346915         92.0       649   17.5  ...   38.0
# 2312               20.395683         92.0      3575   17.2  ...   46.0
# 2920               46.830275         92.0     16997   17.1  ...   86.0
# 2921               45.616880         92.0     30930   16.8  ...   85.0
# 2932                8.717409         65.0       420   27.5  ...   69.0
# 2933                0.000000         68.0        31   27.1  ...   67.0
# 2934                0.000000          7.0       998   26.7  ...    7.0
#
#       Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 1127               8.90         66.0        1.9  662.279518   9999617.0
# 1484               6.30         89.0       34.8  862.946312   1949543.0
# 1582               6.35         84.0       24.2   26.152517  12336687.0
# 1583               4.82         64.0       24.7   29.979898   1213711.0
# 1584               5.70          9.0       25.1  146.761540  11695863.0
# 1585               6.70         75.0       25.5  153.259487  11376172.0
# 2306               1.68         64.0        2.2  322.313468   5848692.0
# 2307              12.25         65.0        2.2  287.689194   5658379.0
# 2308              11.66         65.0        2.1  263.145817   5439695.0
# 2309              11.69         73.0        1.9  263.761831   5199549.0
# 2311              11.83         38.0        1.5  227.779471   4739147.0
# 2312              13.63         44.0        1.2  139.314773   4564297.0
# 2920               6.56         85.0       18.6  378.273624   1824125.0
# 2921               7.16         85.0       18.7  341.955625   1531221.0
# 2932               6.44         68.0       30.3  444.765750    129432.0
# 2933               7.13         65.0       33.6  454.366654  12777511.0
# 2934               6.52         68.0       36.7  453.351155  12633897.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 1127                    4.0                  4.0
# 1484                    9.3                  9.2
# 1582                    7.6                  7.5
# 1583                    7.7                  7.6
# 1584                    7.9                  7.7
# 1585                    8.0                  7.9
# 2306                    9.1                  9.1
# 2307                    9.3                  9.3
# 2308                    9.5                  9.5
# 2309                    9.7                  9.8
# 2311                    1.1                  1.2
# 2312                    1.3                  1.4
# 2920                    7.4                  7.4
# 2921                    7.5                  7.5
# 2932                    9.0                  9.0
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
#
#       Income composition of resources  Schooling
# 1127                            0.470        8.6
# 1484                            0.437       10.7
# 1582                            0.362       10.3
# 1583                            0.388       10.4
# 1584                            0.387       10.1
# 1585                            0.391       10.7
# 2306                            0.348        8.0
# 2307                            0.341        7.8
# 2308                            0.332        7.6
# 2309                            0.322        7.4
# 2311                            0.302        7.0
# 2312                            0.292        6.7
# 2920                            0.424        9.8
# 2921                            0.418        9.6
# 2932                            0.406        9.3
# 2933                            0.407        9.2
# 2934                            0.418        9.5
#
# [17 rows x 21 columns]

# %% [markdown]
# **HeatMap**
#
# HeatMap allows us to visualize the correlation and linear relationship among the variables. It can be useful for feature selection as it highlights the correlation between the features. The values closer to 1 indicates strong positive correlation whereas values closer to -1 indicates strong negative correlation.

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(life_expectancy_df.corr(),annot=True,cmap="Greens")
plt.show()

# %% [markdown]
# # **Data Preparation and Model Selection**

# %% [markdown]
# **Spliting the Dataset into feature and target**

# %%
X=life_expectancy_df.drop(columns="Life expectancy ")
Y = life_expectancy_df['Life expectancy ']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=7)

# %%
x_train.shape,y_train.shape
# Out:
# ((2350, 20), (2350,))

# %%
x_test.shape, y_test.shape
# Out:
# ((588, 20), (588,))

# %% [markdown]
# Splitting the dataset into train and test is necessary to see how well the model will perform with unseen data. The sklearn's train_test_split uses holdout method to randomly split the dataset into  train and test set. In this case the train set is made up of 80% of dataset and remaining 20% is converted into test set.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Linear Regression from Scratch

# %%
def compute_cost(X, y, w, b):
    """
    Computes the cost (mean squared error) for linear regression.

    Parameters:
    X (numpy array): Input feature matrix of shape (m, n), where m is the number of samples and n is the number of features.
    y (numpy array): Target vector of shape (m,) containing the actual values.
    w (numpy array): Weight vector of shape (n,) containing the model's weights.
    b (float): Bias term for the model.

    Returns:
    float: The computed cost, which is the mean squared error divided by 2.
    """
    m = len(y)
    y_pred = np.dot(X, w) + b
    cost = np.sum((y_pred - y) ** 2) / (2 * m)  # MSE / 2
    return cost

# %%
def compute_gradient(X, y, w, b):
    """
    Computes the gradients of the cost function with respect to the weights and bias.

    Parameters:
    X (numpy array): Input feature matrix of shape (m, n).
    y (numpy array): Target vector of shape (m,).
    w (numpy array): Weight vector of shape (n,).
    b (float): Bias term for the model.

    Returns:
    tuple: A tuple containing:
        - grad_w (numpy array): Gradient with respect to the weights (shape: n,).
        - grad_b (float): Gradient with respect to the bias (scalar).
    """
    m = len(y)
    y_pred = np.dot(X, w) + b
    error = y_pred - y
    grad_w = np.dot(X.T, error) / m  # Gradient of weights
    grad_b = np.sum(error) / m  # Gradient of bias
    return grad_w, grad_b

# %%
def gradient_descent(X, y, w, b, alpha, n_iter):
    """
    Performs gradient descent to minimize the cost function for linear regression.

    Parameters:
    X (numpy array): Input feature matrix of shape (m, n).
    y (numpy array): Target vector of shape (m,).
    w (numpy array): Initial weight vector of shape (n,).
    b (float): Initial bias term.
    alpha (float): Learning rate (step size).
    n_iter (int): Number of iterations for gradient descent.

    Returns:
    tuple: A tuple containing:
        - w (numpy array): Optimized weight vector (shape: n,).
        - b (float): Optimized bias term.
        - cost_history (list): List of cost values at each 100th iteration.
    """
    cost_history = []
    for i in range(n_iter):
        grad_w, grad_b = compute_gradient(X, y, w, b)
        w -= alpha * grad_w
        b -= alpha * grad_b
        if i % 100 == 0:
            cost = compute_cost(X, y, w, b)
            cost_history.append(cost)
            print(f"Iteration {i}: Cost = {cost:.4f}")
    return w, b, cost_history

# %%
n_features = X_train_scaled.shape[1]  # Number of features
w_initial = np.zeros(n_features)  # Initialize weights to zeros
b_initial = 0.0  # Initialize bias to 0
alpha = 0.01  # Learning rate (step size)
n_iter = 1000  # Number of iterations for gradient descent

# %%
# Train the model using gradient descent
#Stores cost history to track progress
w_final, b_final, cost_history = gradient_descent(X_train_scaled, y_train, w_initial, b_initial, alpha, n_iter)
# Out:
# Iteration 0: Cost = 2392.2513
# Iteration 100: Cost = 323.9100
# Iteration 200: Cost = 50.6720
# Iteration 300: Cost = 14.0503
# Iteration 400: Cost = 9.1311
# Iteration 500: Cost = 8.4642
# Iteration 600: Cost = 8.3694
# Iteration 700: Cost = 8.3526
# Iteration 800: Cost = 8.3469
# Iteration 900: Cost = 8.3432

# %%
y_train_pred = np.dot(X_train_scaled, w_final) + b_final  # Predictions for training data
y_test_pred = np.dot(X_test_scaled, w_final) + b_final  # Predictions for test data Applies the linear regression formula:ypred=Xw+b

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
# Compute evaluation metrics
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print("\nModel Evaluation:")
print(f"Train MSE: {mse_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Train R²: {r2_train:.3f}")
print(f"Test R²: {r2_test:.3f}")
# Out:
# Model Evaluation:
# Train MSE: 16.68
# Test MSE: 18.62
# Train R²: 0.814
# Test R²: 0.800

# %% [markdown]
# **Choosing the right models**:
#  Since the heatmap during EDA showed  linear relationship among the features and variable, for this task we will be choosing Linear Regression due to it being a good fit for  linear relation ship and RandomForest Regressor due to it being an ensemble method.

# %% [markdown]
# ## Initial Models

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# Linear Regression works by fitting a straight line to the data points minimizing the difference between observer and predicted values. It uses equation of a straight line to model a relationship between features and target.

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train_scaled,y_train)  # inputs for building models
# Out:
# LinearRegression()

# %%
y_trainP=lr.predict(X_train_scaled)
y_testP=lr.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
print("For training set:\n")
print(f"RMSE:{np.sqrt(mean_squared_error(y_train,y_trainP))}")

print(f"MSE:{mean_squared_error(y_train,y_trainP)}")
print(f"MAE:{mean_absolute_error(y_train,y_trainP)}")
print(f"R2 Score: {r2_score(y_train,y_trainP)}")
# Out:
# For training set:
#
# RMSE:3.9925932353551654
# MSE:15.940800743003827
# MAE:2.966283283124623
# R2 Score: 0.8223893163776909

# %%
print("For test set:\n")
print(f"RMSE:{np.sqrt(mean_squared_error(y_test,y_testP))}")
print(f"MSE:{mean_squared_error(y_test,y_testP)}")
print(f"MAE:{mean_absolute_error(y_test,y_testP)}")
print(f"R2 Score:{r2_score(y_test,y_testP)}")
# Out:
# For test set:
#
# RMSE:4.226972485828607
# MSE:17.867296395952067
# MAE:3.171216211837633
# R2 Score:0.8077570547244785

# %% [markdown]
# **Observations**
#
# The linear model performs good on both training and test set.The performance is slightly compromised when introduced to unseen data(test set). Overall, the RMSE score and MAE are not so high and r2 score is also 0.80 for test set,indicating model performs good with room for imporvements.

# %% [markdown]
# RandomForestRegressor

# %% [markdown]
# RFR works by training multiple decision trees using random subsets of the training data and features. It combines the prediction of these decision trees to make the final prediction for the target. RFR is robust to outliers.

# %%
from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(random_state=7)
rfr.fit(X_train_scaled,y_train)
# Out:
# RandomForestRegressor(random_state=7)

# %%
y_TrainP=rfr.predict(X_train_scaled)
y_TestP=rfr.predict(X_test_scaled)

# %%
print("For training set:\n")
print(f"RMSE:{np.sqrt(mean_squared_error(y_train,y_TrainP))}")
print(f"MSE:{(mean_squared_error(y_train,y_TrainP))}")
print(f"MAE:{mean_absolute_error(y_train,y_TrainP)}")
print(f"R2 Score:{r2_score(y_train,y_TrainP)}")
# Out:
# For training set:
#
# RMSE:0.6692829122245273
# MSE:0.44793961659574427
# MAE:0.4207970212765976
# R2 Score:0.9950091050752264

# %%
print("For test set:\n")
print(f"RMSE:{np.sqrt(mean_squared_error(y_test,y_TestP))}")
print(f"MSE:{(mean_squared_error(y_test,y_TestP))}")
print(f"MAE:{mean_absolute_error(y_test,y_TestP)}")
print(f"R2 Score:{r2_score(y_test,y_TestP)}")
# Out:
# For test set:
#
# RMSE:2.0989970373788456
# MSE:4.405788562925171
# MAE:1.2611003401360568
# R2 Score:0.9525959747446833

# %% [markdown]
# The RFR model performed expetionally well with Low RMSE and MAE with R2 score being 0.95 indicating a good model perfomance.It indicates that even for test data, the predicted values are close to the actual values. Overall this model performs better compared to Linear Regression.

# %% [markdown]
# ### Hyperparameter tuning for Linear Regression

# %%
from sklearn.model_selection import RandomizedSearchCV
grid={'fit_intercept': [True, False]}
reg1=LinearRegression()
rs_reg=RandomizedSearchCV(estimator=reg1,param_distributions=grid,n_iter=10,cv=5,verbose=2)
rs_reg.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=LinearRegression(),
#                    param_distributions={'fit_intercept': [True, False]},
#                    verbose=2)

# %%
best_params=rs_reg.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'fit_intercept': True}

# %% [markdown]
# ### Feature Selection for Linear Regression

# %% [markdown]
# ### Using SelectKBest,f_regressor
#
# SelectKBest selects the top k features based on statistical tests while f_regressor helps to identify features that are most relevant for predicting the target variable in a regression context.

# %%
from sklearn.feature_selection import SelectKBest, f_regression
selector=SelectKBest(f_regression,k=5)#Selects the top 5 most important features.
selector.fit(X,Y)#Computes F-scores for feature relevance.
x_new=selector.transform(X)#Keeps only the top 5 features.
print("Original shape:", X.shape)  # Before feature selection
print("New shape:", x_new.shape)   # After feature selection
# Out:
# Original shape: (2938, 20)
# New shape: (2938, 5)

# %%
selected_features_lr = x_train.columns[selector.get_support()]#Finds which features were selected. Extracts the names of selected features.
print("Selected Features for Random Forest Classifier:", list(selected_features_lr))
# Out:
# Selected Features for Random Forest Classifier: ['Adult Mortality', ' BMI ', ' HIV/AIDS', 'Income composition of resources', 'Schooling']

# %% [markdown]
# ### HyperParameter Tuning for RandomForestRegressor

# %% [markdown]
# ### Using RandomizeSearchCV
#
# RandomizedSearchCV randomly samples hyperparameters from predefined distributions and performs cross-validation to find the best combination. It is suitable for finding optimal hyperparameters,especially those with large hyperparameter space.

# %%
from sklearn.model_selection import RandomizedSearchCV
grid={"n_estimators":[100,200,500,1000,1200],#Number of trees in the random forest, More trees usually improve accuracy but increase computation time.
      "max_depth":[5,10,20,30],#The maximum depth of each decision tree, None means it will grow until all leaves are pure.
      "max_features":["auto","sqrt"],#Controls how many features are considered at each split. "auto" uses all features, "sqrt" uses total features.
      "min_samples_split":[2,4,6],#Minimum number of samples required to split an internal node. Higher values reduce overfitting.
      "min_samples_leaf":[1,2,4],#Minimum number of samples required in a leaf node. Higher values make trees simpler (less overfitting).
      "criterion": ['squared_error', 'absolute_error']#Measures the quality of a split. 'squared_error' is MSE , 'absolute_error' is MAE.
      }
regr=RandomForestRegressor(random_state=7)
rs_reg=RandomizedSearchCV(estimator=regr,param_distributions=grid,n_iter=5,cv=2,verbose=2)
rs_reg.fit(X_train_scaled,y_train)
# Out:
# Fitting 2 folds for each of 5 candidates, totalling 10 fits
# [CV] END criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=1200; total time=   0.0s
# [CV] END criterion=squared_error, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=1200; total time=   0.0s
# [CV] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=1000; total time=   4.4s
# [CV] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=1000; total time=   4.2s
# [CV] END criterion=absolute_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  27.0s
# [CV] END criterion=absolute_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  27.5s
# [CV] END criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.5s
# RandomizedSearchCV(cv=2, estimator=RandomForestRegressor(random_state=7),
#                    n_iter=5,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error'],
#                                         'max_depth': [5, 10, 20, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 4, 6],
#                                         'n_estimators': [100, 200, 500, 1000,
#                                                          1200]},
#                    verbose=2)

# %%
best_param=rs_reg.best_params_
print(best_param)
# Out:
# {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'criterion': 'absolute_error'}

# %% [markdown]
# ### Feature Selection for randomForest Regressor

# %% [markdown]
# Feature selection helps the model focus on the most important features, improving efficiency and accuracy while Hyperparameter tuning is essential to optimize the model's performance by finding the most suitable settings for parameters.Hyperparameter tuning is essential to optimize the model's performance by finding the most suitable settings for parameters

# %%
from sklearn.feature_selection import SelectFromModel
model = SelectFromModel(rfr, prefit=True)#(previously trained model, True= already been trained) Uses trained rfr to select important features.
X_new = model.transform(X)
print("Original shape:", X.shape)  # Before feature selection
print("New shape:", X_new.shape)   # After feature selection
# Out:
# Original shape: (2938, 20)
# New shape: (2938, 3)

# %%
selected_features_rfc = x_train.columns[model.get_support()]
print("Selected Features for Random Forest Classifier:", list(selected_features_rfc))
# Out:
# Selected Features for Random Forest Classifier: ['Adult Mortality', ' HIV/AIDS', 'Income composition of resources']

# %% [markdown]
# By using the  embedded method to select optimal features for the Random Forest Regressor (RFR), the algorithm identified the most informative features and chose 3 out of the 20 available features.

# %% [markdown]
# ##Final model

# %% [markdown]
# New training and testing sets after feature selection (RFR)

# %%
x_train_rfr,x_test_rfr,y_train_rfr,y_test_rfr=train_test_split(X_new,Y,test_size=0.2,random_state=7)

# %% [markdown]
# **Training the model after feature selection and hyperparamter tuning**

# %%
final_rfr=RandomForestRegressor(**best_param,random_state=7)
final_rfr.fit(x_train_rfr,y_train_rfr)
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=30,
#                       max_features='sqrt', n_estimators=1000, random_state=7)

# %%
y_TrainP=final_rfr.predict(x_train_rfr)
y_TestP=final_rfr.predict(x_test_rfr)

# %%
print("For training set:\n")
print(f"RMSE:{np.sqrt(mean_squared_error(y_train_rfr,y_TrainP))}")
print(f"MSE:{(mean_squared_error(y_train_rfr,y_TrainP))}")
print(f"MAE:{mean_absolute_error(y_train_rfr,y_TrainP)}")
print(f"R2 Score:{r2_score(y_train_rfr,y_TrainP)}")
# Out:
# For training set:
#
# RMSE:0.9154252553751818
# MSE:0.8380033981787168
# MAE:0.615508808510636
# R2 Score:0.9906630564657385

# %%
print("For test set:\n")
print(f"RMSE:{np.sqrt(mean_squared_error(y_test_rfr,y_TestP))}")
print(f"MSE:{(mean_squared_error(y_test_rfr,y_TestP))}")
print(f"MAE:{mean_absolute_error(y_test_rfr,y_TestP)}")
print(f"R2 Score:{r2_score(y_test_rfr,y_TestP)}")
# Out:
# For test set:
#
# RMSE:2.3215419881058037
# MSE:5.389557202538248
# MAE:1.5695621598639289
# R2 Score:0.9420111287468433

# %% [markdown]
# The RFR model performed expetionally well with Low RMSE and MAE with R2 score being 0.94 indicating a good model perfomance.It indicates that even for test data, the predicted values are close to the actual values. Although there is a very slight drop in the metric score, it still be considered an optimal model as it uses less features (3) compared to initial(20) effectively reducing the dimension and computational costs without any significant difference.

# %% [markdown]
# ## **Conclusion**
# Overall, the RandomForest Regressor outperfomed the Linear Regression for both the initial and final model. For RFR, after the hyperparameter tuning and feature selection, there were slight drops in the accuracy however no significant drop was seen. For Linear Regression, the hyperparameter tuning as well as feature selection caused degradation in the model's performance.
#
# The hyperparameter tuning and feature selection helped to reduce the dimensionality and reduce the complexity as well as the overall computational cost without compromising the performance of the RandomForest Regressor.
# In conclusion, for this regression  task RandomForest Regressor is the best model as it was able to get high accuracy with low RMSE and MAE and good r2 score with less features without compromising the initial accuracy of the model.
